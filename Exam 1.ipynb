# %%
#(a) Create a “list” of ten random numbers inside the list (to do this use a random number generator random() 
#that returns a floating point number between 0 and 1 – you may have to “from random import random” 
#first before calling this function). 
#(b) Iterate through the list and calculate the average of all the numbers in the list

import random
my_list=[]
for i in range(10):
    my_list.append(random.random())
print(my_list)
print(sum(my_list)/len(my_list))
# Out:
# [0.11931187432078694, 0.8156654112937356, 0.7672886554667941, 0.7041804690755282, 0.545619712158631, 0.4325670095914025, 0.22763565749930004, 0.10602507516359194, 0.7438856220651398, 0.23096696025840047]
# 0.46931464468933104

# %%
#2. Read iris.csv into a pandas data frame and do the following tasks. 
 

import pandas as pd
iris_csv = pd.read_csv("iris.csv")
print(iris_csv)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
#(a) Extract the second row of values and store those values in a “list” object
second_row=iris_csv.loc[2]
#print(type(second_row))

# %%
print(second_row)
# Out:
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object

# %%
print(type(second_row))
# Out:
# <class 'pandas.core.series.Series'>

# %%
second_row_list=second_row.tolist()

# %%
print(type(second_row_list))
# Out:
# <class 'list'>

# %%
#(b) Extract the sepal length column alone and print the column 
cols = iris_csv[['sepal_length']]
print(cols.iloc[0:150])
# Out:
#      sepal_length
# 0             5.1
# 1             4.9
# 2             4.7
# 3             4.6
# 4             5.0
# 5             5.4
# 6             4.6
# 7             5.0
# 8             4.4
# 9             4.9
# 10            5.4
# 11            4.8
# 12            4.8
# 13            4.3
# 14            5.8
# 15            5.7
# 16            5.4
# 17            5.1
# 18            5.7
# 19            5.1
# 20            5.4
# 21            5.1
# 22            4.6
# 23            5.1
# 24            4.8
# 25            5.0
# 26            5.0
# 27            5.2
# 28            5.2
# 29            4.7
# ..            ...
# 120           6.9
# 121           5.6
# 122           7.7
# 123           6.3
# 124           6.7
# 125           7.2
# 126           6.2
# 127           6.1
# 128           6.4
# 129           7.2
# 130           7.4
# 131           7.9
# 132           6.4
# 133           6.3
# 134           6.1
# 135           7.7
# 136           6.3
# 137           6.4
# ...

# %%
#c
df=pd.DataFrame(iris_csv.iloc[0:5])
df=df.append(iris_csv.iloc[147:150])
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
#3. Write code to clearly show one example immutability in Python. 


abc="Immutability in Python"
abc[0] = 'M'
householdsprint(abc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-1cb383fd1848> in <module>
#       1 abc="Immutability in Python"
# ----> 2 abc[0] = 'M'
#       3 print(abc)
#
# TypeError: 'str' object does not support item assignment

# %%
#4. (a) In the California housing dataset identify the top three variables with the highest absolute value in correlation with median income – you can do this by looking at the correlation values manually as well, no need to automate this 
#(b) Then generate three scatter plots, each showing how median income relates to each of the three variables (in other words, if x1, x2 and x3 and the three variables with highest absolute value of correlation then show three scatter plots of median income against x1, x2 and x3 respectively). 

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
housing = pd.read_csv("housing.csv")

# %%
print(housing.corr())
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
corr_matrix = housing.corr()
corr_matrix["median_income"].sort_values()
# Out:
# housing_median_age   -0.119034
# latitude             -0.079809
# longitude            -0.015176
# total_bedrooms       -0.007723
# population            0.004834
# households            0.013033
# total_rooms           0.198050
# median_house_value    0.688075
# median_income         1.000000
# Name: median_income, dtype: float64

# %%
housing.plot(kind="scatter",x="median_house_value",y="median_income", alpha=0.1)

# %%
housing.plot(kind="scatter",x="total_rooms",y="median_income", alpha=0.1)

# %%
housing.plot(kind="scatter",x="households",y="median_income", alpha=0.1)
